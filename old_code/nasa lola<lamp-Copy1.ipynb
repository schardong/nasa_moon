# %%
import math
import numpy as np
import sys
#import cv2
import pickle
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt

# %%
input_filename = "LDEM_75S_120M.IMG"
shape = (7624, 7624) # matrix size
dtype = np.int16 # big-endian unsigned integer (16bit)
output_filename = "albedo.PNG"

# %%
# Reading.
fid = open(input_filename, 'rb')
data = np.fromfile(fid, dtype)
image = np.reshape(data, shape)

# %%
min(data)
# Out:
# -15526

# %%
max(data)
# Out:
# 14050

# %%
print(image)
# Out:
# [[ -428  -483  -539 ...  1597  1639  1673]
#  [ -411  -475  -537 ...  1653  1692  1725]
#  [ -410  -465  -534 ...  1698  1728  1768]
#  ...
#  [-4997 -5030 -5074 ...   363   359   347]
#  [-5025 -5050 -5086 ...   382   372   355]
#  [-5042 -5063 -5095 ...   392   381   364]]

# %%
# Display.
plt.imshow(image)
plt.savefig(output_filename)
plt.show()

# %%
distance =
